# %% [markdown]
# # V. Camera localization - Test on unseen images

# %%
import torch
import matplotlib.pyplot as plt
import time
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/ANAIS2023-PoseNet-Lab
from pose_resnet import *
from utils import *
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# [Errno 2] No such file or directory: '/content/drive/MyDrive/ANAIS2023-PoseNet-Lab'
# /content
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-ae138d8dc70b> in <cell line: 7>()
#       5 drive.mount('/content/drive')
#       6 get_ipython().run_line_magic('cd', '/content/drive/MyDrive/ANAIS2023-PoseNet-Lab')
# ----> 7 from pose_resnet import *
#       8 from utils import *
#
# ModuleNotFoundError: No module named 'pose_resnet'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# ...

# %%
def load_single_image(image_path):
    # Define the transformations
    transform = transforms.Compose([
        transforms.Resize(260),
        transforms.CenterCrop(250),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
    ])

    image = Image.open(image_path)
    image = transform(image)
    return image.unsqueeze(0)

# %% [markdown]
# ## Main

# %%
def main():
    # load the model
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    model = PoseResNet().to(device)
    model.load_state_dict(torch.load("posenet_weigths.pth", map_location=device))
    model.eval().to(device)

    # Load the image
    im_day_night_1_1 = load_single_image("./Data_day_night/day_night_1_1.jpg")
    im_day_night_1_2 = load_single_image("./Data_day_night/day_night_1_2.jpg")
    im_day_night_1_3 = load_single_image("./Data_day_night/day_night_1_3.jpg")
    im_day_night_2_1 = load_single_image("./Data_day_night/day_night_2_1.jpg")
    im_day_night_2_2 = load_single_image("./Data_day_night/day_night_2_2.jpg")
    im_day_night_2_3 = load_single_image("./Data_day_night/day_night_2_3.jpg")
    im_day_night_3_1 = load_single_image("./Data_day_night/day_night_3_1.jpg")
    im_day_night_3_2 = load_single_image("./Data_day_night/day_night_3_2.jpg")
    im_day_night_3_3 = load_single_image("./Data_day_night/day_night_3_3.jpg")

    # Run the model on the image set 1 and print localization
    # TODO !

    # Run the model on the image set 2 and print localization
    # TODO !

    # Run the model on the image set 3 and print localization
    # TODO !

if __name__ == "__main__":
    main()
# Out:
# [  4.7113814  -15.304018     1.6436361    0.6410364    0.61091596
#   -0.1485484    0.19634026]
# [  3.3904321  -17.484617     1.7372748    0.7154814    0.5722411
#   -0.20979953   0.25880906]
# [  9.128573   -15.856824     1.5822105    0.6632525    0.5545315
#   -0.09197499   0.11756048]
# [  4.196854   -19.570839     1.8157636    0.697377     0.601798
#   -0.24040064   0.3139829 ]
# [ 19.878126   -24.98924      1.7373711    0.66805935   0.5966599
#   -0.07889539   0.09393059]
# [ -1.8225987  -16.391151     1.7016013    0.6155672    0.60000473
#   -0.25920007   0.32842174]
# [ 11.184833   -18.434961     1.7335932    0.70918477   0.6337833
#   -0.08169224   0.08521104]
# [ 15.35048    -19.026424     1.6334612    0.6619772    0.61547905
#   -0.05880686   0.08459085]
# [ 11.857195   -19.010355     1.790261     0.6555239    0.70271295
#   -0.07890768   0.09522161]
